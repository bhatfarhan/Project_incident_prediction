# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\farhanfarooq\\Desktop\\Project Incident Prediction\\incident_event_log.csv")
df
# Out:
#             number incident_state  active  reassignment_count  reopen_count  \
# 0       INC0000045            New    True                   0             0
# 1       INC0000045       Resolved    True                   0             0
# 2       INC0000045       Resolved    True                   0             0
# 3       INC0000045         Closed   False                   0             0
# 4       INC0000047            New    True                   0             0
# ...            ...            ...     ...                 ...           ...
# 141707  INC0120835         Closed   False                   1             0
# 141708  INC0121064         Active    True                   0             0
# 141709  INC0121064         Active    True                   1             0
# 141710  INC0121064       Resolved    True                   1             0
# 141711  INC0121064         Closed   False                   1             0
#
#         sys_mod_count  made_sla    caller_id       opened_by        opened_at  \
# 0                   0      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 1                   2      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 2                   3      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 3                   4      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 4                   0      True  Caller 2403  Opened by  397  29/2/2016 04:40
# ...               ...       ...          ...             ...              ...
# 141707              4      True   Caller 116   Opened by  12  16/2/2017 09:09
# 141708              0      True   Caller 116   Opened by  12  16/2/2017 14:17
# 141709              1      True   Caller 116   Opened by  12  16/2/2017 14:17
# 141710              2      True   Caller 116   Opened by  12  16/2/2017 14:17
# 141711              3      True   Caller 116   Opened by  12  16/2/2017 14:17
#
#         ... u_priority_confirmation         notify problem_id rfc vendor  \
# 0       ...                   False  Do Not Notify          ?   ?      ?
# 1       ...                   False  Do Not Notify          ?   ?      ?
# 2       ...                   False  Do Not Notify          ?   ?      ?
# 3       ...                   False  Do Not Notify          ?   ?      ?
# 4       ...                   False  Do Not Notify          ?   ?      ?
# ...     ...                     ...            ...        ...  ..    ...
# 141707  ...                    True  Do Not Notify          ?   ?      ?
# 141708  ...                   False  Do Not Notify          ?   ?      ?
# 141709  ...                   False  Do Not Notify          ?   ?      ?
# 141710  ...                    True  Do Not Notify          ?   ?      ?
# 141711  ...                    True  Do Not Notify          ?   ?      ?
#
#        caused_by closed_code      resolved_by      resolved_at  \
# 0              ?      code 5  Resolved by 149  29/2/2016 11:29
# 1              ?      code 5  Resolved by 149  29/2/2016 11:29
# 2              ?      code 5  Resolved by 149  29/2/2016 11:29
# 3              ?      code 5  Resolved by 149  29/2/2016 11:29
# 4              ?      code 5   Resolved by 81   1/3/2016 09:52
# ...          ...         ...              ...              ...
# 141707         ?      code 9    Resolved by 9  16/2/2017 09:53
# 141708         ?      code 6    Resolved by 9  16/2/2017 16:38
# 141709         ?      code 6    Resolved by 9  16/2/2017 16:38
# 141710         ?      code 6    Resolved by 9  16/2/2017 16:38
# 141711         ?      code 6    Resolved by 9  16/2/2017 16:38
#
#               closed_at
# 0        5/3/2016 12:00
# 1        5/3/2016 12:00
# 2        5/3/2016 12:00
# 3        5/3/2016 12:00
# 4        6/3/2016 10:00
# ...                 ...
# 141707  16/2/2017 09:53
# 141708  16/2/2017 16:38
# 141709  16/2/2017 16:38
# 141710  16/2/2017 16:38
# 141711  16/2/2017 16:38
#
# [141712 rows x 36 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas_profiling as pp
import sweetviz as sv

# %%
df.tail(10)
# Out:
#             number      incident_state  active  reassignment_count  \
# 141702  INC0120495  Awaiting User Info    True                   1
# 141703  INC0120495              Closed   False                   1
# 141704  INC0120835              Active    True                   0
# 141705  INC0120835              Active    True                   1
# 141706  INC0120835            Resolved    True                   1
# 141707  INC0120835              Closed   False                   1
# 141708  INC0121064              Active    True                   0
# 141709  INC0121064              Active    True                   1
# 141710  INC0121064            Resolved    True                   1
# 141711  INC0121064              Closed   False                   1
#
#         reopen_count  sys_mod_count  made_sla   caller_id      opened_by  \
# 141702             0              4      True  Caller 323  Opened by  14
# 141703             0              5      True  Caller 323  Opened by  14
# 141704             0              0      True  Caller 116  Opened by  12
# 141705             0              1      True  Caller 116  Opened by  12
# 141706             0              3      True  Caller 116  Opened by  12
# 141707             0              4      True  Caller 116  Opened by  12
# 141708             0              0      True  Caller 116  Opened by  12
# 141709             0              1      True  Caller 116  Opened by  12
# 141710             0              2      True  Caller 116  Opened by  12
# 141711             0              3      True  Caller 116  Opened by  12
#
#               opened_at  ... u_priority_confirmation         notify  \
# 141702  15/2/2017 11:58  ...                   False  Do Not Notify
# 141703  15/2/2017 11:58  ...                   False  Do Not Notify
# 141704  16/2/2017 09:09  ...                   False  Do Not Notify
# 141705  16/2/2017 09:09  ...                   False  Do Not Notify
# 141706  16/2/2017 09:09  ...                    True  Do Not Notify
# 141707  16/2/2017 09:09  ...                    True  Do Not Notify
# 141708  16/2/2017 14:17  ...                   False  Do Not Notify
# 141709  16/2/2017 14:17  ...                   False  Do Not Notify
# 141710  16/2/2017 14:17  ...                    True  Do Not Notify
# 141711  16/2/2017 14:17  ...                    True  Do Not Notify
#
#        problem_id rfc vendor caused_by closed_code    resolved_by  \
# 141702          ?   ?      ?         ?           ?              ?
# 141703          ?   ?      ?         ?           ?              ?
# 141704          ?   ?      ?         ?      code 9  Resolved by 9
# 141705          ?   ?      ?         ?      code 9  Resolved by 9
# 141706          ?   ?      ?         ?      code 9  Resolved by 9
# 141707          ?   ?      ?         ?      code 9  Resolved by 9
# 141708          ?   ?      ?         ?      code 6  Resolved by 9
# 141709          ?   ?      ?         ?      code 6  Resolved by 9
# 141710          ?   ?      ?         ?      code 6  Resolved by 9
# 141711          ?   ?      ?         ?      code 6  Resolved by 9
#
#             resolved_at        closed_at
# 141702                ?  16/2/2017 09:51
# 141703                ?  16/2/2017 09:51
# 141704  16/2/2017 09:53  16/2/2017 09:53
# 141705  16/2/2017 09:53  16/2/2017 09:53
# 141706  16/2/2017 09:53  16/2/2017 09:53
# 141707  16/2/2017 09:53  16/2/2017 09:53
# 141708  16/2/2017 16:38  16/2/2017 16:38
# 141709  16/2/2017 16:38  16/2/2017 16:38
# 141710  16/2/2017 16:38  16/2/2017 16:38
# 141711  16/2/2017 16:38  16/2/2017 16:38
#
# [10 rows x 36 columns]

# %%
#Data Structure
type(df)
df.shape
# Out:
# (141712, 36)

# %%
df.dtypes
# Out:
# number                     object
# incident_state             object
# active                       bool
# reassignment_count          int64
# reopen_count                int64
# sys_mod_count               int64
# made_sla                     bool
# caller_id                  object
# opened_by                  object
# opened_at                  object
# sys_created_by             object
# sys_created_at             object
# sys_updated_by             object
# sys_updated_at             object
# contact_type               object
# location                   object
# category                   object
# subcategory                object
# u_symptom                  object
# cmdb_ci                    object
# impact                     object
# urgency                    object
# priority                   object
# assignment_group           object
# assigned_to                object
# knowledge                    bool
# u_priority_confirmation      bool
# notify                     object
# problem_id                 object
# rfc                        object
# vendor                     object
# caused_by                  object
# closed_code                object
# resolved_by                object
# resolved_at                object
# closed_at                  object
# dtype: object

# %% [markdown]
# # Data Type Conversion

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141712 entries, 0 to 141711
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   number                   141712 non-null  object
#  1   incident_state           141712 non-null  object
#  2   active                   141712 non-null  bool
#  3   reassignment_count       141712 non-null  int64
#  4   reopen_count             141712 non-null  int64
#  5   sys_mod_count            141712 non-null  int64
#  6   made_sla                 141712 non-null  bool
#  7   caller_id                141712 non-null  object
#  8   opened_by                141712 non-null  object
#  9   opened_at                141712 non-null  object
#  10  sys_created_by           141712 non-null  object
#  11  sys_created_at           141712 non-null  object
#  12  sys_updated_by           141712 non-null  object
#  13  sys_updated_at           141712 non-null  object
#  14  contact_type             141712 non-null  object
#  15  location                 141712 non-null  object
#  16  category                 141712 non-null  object
#  17  subcategory              141712 non-null  object
#  18  u_symptom                141712 non-null  object
#  19  cmdb_ci                  141712 non-null  object
#  20  impact                   141712 non-null  object
#  21  urgency                  141712 non-null  object
#  22  priority                 141712 non-null  object
#  23  assignment_group         141712 non-null  object
#  24  assigned_to              141712 non-null  object
#  25  knowledge                141712 non-null  bool
#  26  u_priority_confirmation  141712 non-null  bool
#  27  notify                   141712 non-null  object
#  28  problem_id               141712 non-null  object
#  29  rfc                      141712 non-null  object
#  30  vendor                   141712 non-null  object
#  31  caused_by                141712 non-null  object
#  32  closed_code              141712 non-null  object
#  33  resolved_by              141712 non-null  object
#  34  resolved_at              141712 non-null  object
#  35  closed_at                141712 non-null  object
# dtypes: bool(4), int64(3), object(29)
# memory usage: 35.1+ MB

# %%
df1 = df.iloc[:,0:]
df1
# Out:
#             number incident_state  active  reassignment_count  reopen_count  \
# 0       INC0000045            New    True                   0             0
# 1       INC0000045       Resolved    True                   0             0
# 2       INC0000045       Resolved    True                   0             0
# 3       INC0000045         Closed   False                   0             0
# 4       INC0000047            New    True                   0             0
# ...            ...            ...     ...                 ...           ...
# 141707  INC0120835         Closed   False                   1             0
# 141708  INC0121064         Active    True                   0             0
# 141709  INC0121064         Active    True                   1             0
# 141710  INC0121064       Resolved    True                   1             0
# 141711  INC0121064         Closed   False                   1             0
#
#         sys_mod_count  made_sla    caller_id       opened_by        opened_at  \
# 0                   0      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 1                   2      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 2                   3      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 3                   4      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 4                   0      True  Caller 2403  Opened by  397  29/2/2016 04:40
# ...               ...       ...          ...             ...              ...
# 141707              4      True   Caller 116   Opened by  12  16/2/2017 09:09
# 141708              0      True   Caller 116   Opened by  12  16/2/2017 14:17
# 141709              1      True   Caller 116   Opened by  12  16/2/2017 14:17
# 141710              2      True   Caller 116   Opened by  12  16/2/2017 14:17
# 141711              3      True   Caller 116   Opened by  12  16/2/2017 14:17
#
#         ... u_priority_confirmation         notify problem_id rfc vendor  \
# 0       ...                   False  Do Not Notify          ?   ?      ?
# 1       ...                   False  Do Not Notify          ?   ?      ?
# 2       ...                   False  Do Not Notify          ?   ?      ?
# 3       ...                   False  Do Not Notify          ?   ?      ?
# 4       ...                   False  Do Not Notify          ?   ?      ?
# ...     ...                     ...            ...        ...  ..    ...
# 141707  ...                    True  Do Not Notify          ?   ?      ?
# 141708  ...                   False  Do Not Notify          ?   ?      ?
# 141709  ...                   False  Do Not Notify          ?   ?      ?
# 141710  ...                    True  Do Not Notify          ?   ?      ?
# 141711  ...                    True  Do Not Notify          ?   ?      ?
#
#        caused_by closed_code      resolved_by      resolved_at  \
# 0              ?      code 5  Resolved by 149  29/2/2016 11:29
# 1              ?      code 5  Resolved by 149  29/2/2016 11:29
# 2              ?      code 5  Resolved by 149  29/2/2016 11:29
# 3              ?      code 5  Resolved by 149  29/2/2016 11:29
# 4              ?      code 5   Resolved by 81   1/3/2016 09:52
# ...          ...         ...              ...              ...
# 141707         ?      code 9    Resolved by 9  16/2/2017 09:53
# 141708         ?      code 6    Resolved by 9  16/2/2017 16:38
# 141709         ?      code 6    Resolved by 9  16/2/2017 16:38
# 141710         ?      code 6    Resolved by 9  16/2/2017 16:38
# 141711         ?      code 6    Resolved by 9  16/2/2017 16:38
#
#               closed_at
# 0        5/3/2016 12:00
# 1        5/3/2016 12:00
# 2        5/3/2016 12:00
# 3        5/3/2016 12:00
# 4        6/3/2016 10:00
# ...                 ...
# 141707  16/2/2017 09:53
# 141708  16/2/2017 16:38
# 141709  16/2/2017 16:38
# 141710  16/2/2017 16:38
# 141711  16/2/2017 16:38
#
# [141712 rows x 36 columns]

# %%
data = df1.copy()

# %%
data
# Out:
#             number incident_state  active  reassignment_count  reopen_count  \
# 0       INC0000045            New    True                   0             0
# 1       INC0000045       Resolved    True                   0             0
# 2       INC0000045       Resolved    True                   0             0
# 3       INC0000045         Closed   False                   0             0
# 4       INC0000047            New    True                   0             0
# ...            ...            ...     ...                 ...           ...
# 141707  INC0120835         Closed   False                   1             0
# 141708  INC0121064         Active    True                   0             0
# 141709  INC0121064         Active    True                   1             0
# 141710  INC0121064       Resolved    True                   1             0
# 141711  INC0121064         Closed   False                   1             0
#
#         sys_mod_count  made_sla    caller_id       opened_by        opened_at  \
# 0                   0      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 1                   2      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 2                   3      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 3                   4      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 4                   0      True  Caller 2403  Opened by  397  29/2/2016 04:40
# ...               ...       ...          ...             ...              ...
# 141707              4      True   Caller 116   Opened by  12  16/2/2017 09:09
# 141708              0      True   Caller 116   Opened by  12  16/2/2017 14:17
# 141709              1      True   Caller 116   Opened by  12  16/2/2017 14:17
# 141710              2      True   Caller 116   Opened by  12  16/2/2017 14:17
# 141711              3      True   Caller 116   Opened by  12  16/2/2017 14:17
#
#         ... u_priority_confirmation         notify problem_id rfc vendor  \
# 0       ...                   False  Do Not Notify          ?   ?      ?
# 1       ...                   False  Do Not Notify          ?   ?      ?
# 2       ...                   False  Do Not Notify          ?   ?      ?
# 3       ...                   False  Do Not Notify          ?   ?      ?
# 4       ...                   False  Do Not Notify          ?   ?      ?
# ...     ...                     ...            ...        ...  ..    ...
# 141707  ...                    True  Do Not Notify          ?   ?      ?
# 141708  ...                   False  Do Not Notify          ?   ?      ?
# 141709  ...                   False  Do Not Notify          ?   ?      ?
# 141710  ...                    True  Do Not Notify          ?   ?      ?
# 141711  ...                    True  Do Not Notify          ?   ?      ?
#
#        caused_by closed_code      resolved_by      resolved_at  \
# 0              ?      code 5  Resolved by 149  29/2/2016 11:29
# 1              ?      code 5  Resolved by 149  29/2/2016 11:29
# 2              ?      code 5  Resolved by 149  29/2/2016 11:29
# 3              ?      code 5  Resolved by 149  29/2/2016 11:29
# 4              ?      code 5   Resolved by 81   1/3/2016 09:52
# ...          ...         ...              ...              ...
# 141707         ?      code 9    Resolved by 9  16/2/2017 09:53
# 141708         ?      code 6    Resolved by 9  16/2/2017 16:38
# 141709         ?      code 6    Resolved by 9  16/2/2017 16:38
# 141710         ?      code 6    Resolved by 9  16/2/2017 16:38
# 141711         ?      code 6    Resolved by 9  16/2/2017 16:38
#
#               closed_at
# 0        5/3/2016 12:00
# 1        5/3/2016 12:00
# 2        5/3/2016 12:00
# 3        5/3/2016 12:00
# 4        6/3/2016 10:00
# ...                 ...
# 141707  16/2/2017 09:53
# 141708  16/2/2017 16:38
# 141709  16/2/2017 16:38
# 141710  16/2/2017 16:38
# 141711  16/2/2017 16:38
#
# [141712 rows x 36 columns]

# %% [markdown]
# # Replacing the '?' with NAN

# %%
data.replace('?', np.nan, inplace=True)

# %%
data.isnull().sum()
# Out:
# number                          0
# incident_state                  0
# active                          0
# reassignment_count              0
# reopen_count                    0
# sys_mod_count                   0
# made_sla                        0
# caller_id                      29
# opened_by                    4835
# opened_at                       0
# sys_created_by              53076
# sys_created_at              53076
# sys_updated_by                  0
# sys_updated_at                  0
# contact_type                    0
# location                       76
# category                       78
# subcategory                   111
# u_symptom                   32964
# cmdb_ci                    141267
# impact                          0
# urgency                         0
# priority                        0
# assignment_group            14213
# assigned_to                 27496
# knowledge                       0
# u_priority_confirmation         0
# notify                          0
# problem_id                 139417
# rfc                        140721
# vendor                     141468
# caused_by                  141689
# closed_code                   714
# resolved_by                   226
# resolved_at                  3141
# closed_at                       0
# dtype: int64

# %%
data.head()
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
# 2  INC0000045       Resolved    True                   0             0
# 3  INC0000045         Closed   False                   0             0
# 4  INC0000047            New    True                   0             0
#
#    sys_mod_count  made_sla    caller_id       opened_by        opened_at  ...  \
# 0              0      True  Caller 2403    Opened by  8  29/2/2016 01:16  ...
# 1              2      True  Caller 2403    Opened by  8  29/2/2016 01:16  ...
# 2              3      True  Caller 2403    Opened by  8  29/2/2016 01:16  ...
# 3              4      True  Caller 2403    Opened by  8  29/2/2016 01:16  ...
# 4              0      True  Caller 2403  Opened by  397  29/2/2016 04:40  ...
#
#   u_priority_confirmation         notify problem_id  rfc vendor caused_by  \
# 0                   False  Do Not Notify        NaN  NaN    NaN       NaN
# 1                   False  Do Not Notify        NaN  NaN    NaN       NaN
# 2                   False  Do Not Notify        NaN  NaN    NaN       NaN
# 3                   False  Do Not Notify        NaN  NaN    NaN       NaN
# 4                   False  Do Not Notify        NaN  NaN    NaN       NaN
#
#   closed_code      resolved_by      resolved_at       closed_at
# 0      code 5  Resolved by 149  29/2/2016 11:29  5/3/2016 12:00
# 1      code 5  Resolved by 149  29/2/2016 11:29  5/3/2016 12:00
# 2      code 5  Resolved by 149  29/2/2016 11:29  5/3/2016 12:00
# 3      code 5  Resolved by 149  29/2/2016 11:29  5/3/2016 12:00
# 4      code 5   Resolved by 81   1/3/2016 09:52  6/3/2016 10:00
#
# [5 rows x 36 columns]

# %% [markdown]
# # Changing the datatypes for opened_at & closed_at columns

# %%
columns_to_change_to_datetime = ['closed_at', 'opened_at' ]

for i in columns_to_change_to_datetime:
    data[i] = data[i].astype('datetime64[ns]')

# %%
data.head()
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
# 2  INC0000045       Resolved    True                   0             0
# 3  INC0000045         Closed   False                   0             0
# 4  INC0000047            New    True                   0             0
#
#    sys_mod_count  made_sla    caller_id       opened_by           opened_at  \
# 0              0      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 1              2      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 2              3      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 3              4      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 4              0      True  Caller 2403  Opened by  397 2016-02-29 04:40:00
#
#    ... u_priority_confirmation         notify problem_id  rfc vendor  \
# 0  ...                   False  Do Not Notify        NaN  NaN    NaN
# 1  ...                   False  Do Not Notify        NaN  NaN    NaN
# 2  ...                   False  Do Not Notify        NaN  NaN    NaN
# 3  ...                   False  Do Not Notify        NaN  NaN    NaN
# 4  ...                   False  Do Not Notify        NaN  NaN    NaN
#
#   caused_by closed_code      resolved_by      resolved_at           closed_at
# 0       NaN      code 5  Resolved by 149  29/2/2016 11:29 2016-05-03 12:00:00
# 1       NaN      code 5  Resolved by 149  29/2/2016 11:29 2016-05-03 12:00:00
# 2       NaN      code 5  Resolved by 149  29/2/2016 11:29 2016-05-03 12:00:00
# 3       NaN      code 5  Resolved by 149  29/2/2016 11:29 2016-05-03 12:00:00
# 4       NaN      code 5   Resolved by 81   1/3/2016 09:52 2016-06-03 10:00:00
#
# [5 rows x 36 columns]

# %%
data.dtypes
# Out:
# number                             object
# incident_state                     object
# active                               bool
# reassignment_count                  int64
# reopen_count                        int64
# sys_mod_count                       int64
# made_sla                             bool
# caller_id                          object
# opened_by                          object
# opened_at                  datetime64[ns]
# sys_created_by                     object
# sys_created_at                     object
# sys_updated_by                     object
# sys_updated_at                     object
# contact_type                       object
# location                           object
# category                           object
# subcategory                        object
# u_symptom                          object
# cmdb_ci                            object
# impact                             object
# urgency                            object
# priority                           object
# assignment_group                   object
# assigned_to                        object
# knowledge                            bool
# u_priority_confirmation              bool
# notify                             object
# problem_id                         object
# rfc                                object
# vendor                             object
# caused_by                          object
# closed_code                        object
# resolved_by                        object
# resolved_at                        object
# closed_at                  datetime64[ns]
# dtype: object

# %%
print('percentage of missing values'.upper())
data.isnull().sum()/data.shape[0]*100
# Out:
# PERCENTAGE OF MISSING VALUES
# number                      0.000000
# incident_state              0.000000
# active                      0.000000
# reassignment_count          0.000000
# reopen_count                0.000000
# sys_mod_count               0.000000
# made_sla                    0.000000
# caller_id                   0.020464
# opened_by                   3.411849
# opened_at                   0.000000
# sys_created_by             37.453427
# sys_created_at             37.453427
# sys_updated_by              0.000000
# sys_updated_at              0.000000
# contact_type                0.000000
# location                    0.053630
# category                    0.055041
# subcategory                 0.078328
# u_symptom                  23.261262
# cmdb_ci                    99.685983
# impact                      0.000000
# urgency                     0.000000
# priority                    0.000000
# assignment_group           10.029496
# assigned_to                19.402732
# knowledge                   0.000000
# u_priority_confirmation     0.000000
# notify                      0.000000
# problem_id                 98.380518
# rfc                        99.300694
# vendor                     99.827820
# caused_by                  99.983770
# closed_code                 0.503839
# resolved_by                 0.159478
# resolved_at                 2.216467
# closed_at                   0.000000
# dtype: float64

# %% [markdown]
# # Dropping columns with more than 90% missing values

# %%
data1 = data.drop(['problem_id','rfc','vendor','caused_by','cmdb_ci'],axis=1)

# %%
data1.shape
# Out:
# (141712, 31)

# %%
data1.head()
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
# 2  INC0000045       Resolved    True                   0             0
# 3  INC0000045         Closed   False                   0             0
# 4  INC0000047            New    True                   0             0
#
#    sys_mod_count  made_sla    caller_id       opened_by           opened_at  \
# 0              0      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 1              2      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 2              3      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 3              4      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 4              0      True  Caller 2403  Opened by  397 2016-02-29 04:40:00
#
#    ...      priority assignment_group  assigned_to knowledge  \
# 0  ...  3 - Moderate         Group 56          NaN      True
# 1  ...  3 - Moderate         Group 56          NaN      True
# 2  ...  3 - Moderate         Group 56          NaN      True
# 3  ...  3 - Moderate         Group 56          NaN      True
# 4  ...  3 - Moderate         Group 70  Resolver 89      True
#
#   u_priority_confirmation         notify closed_code      resolved_by  \
# 0                   False  Do Not Notify      code 5  Resolved by 149
# 1                   False  Do Not Notify      code 5  Resolved by 149
# 2                   False  Do Not Notify      code 5  Resolved by 149
# 3                   False  Do Not Notify      code 5  Resolved by 149
# 4                   False  Do Not Notify      code 5   Resolved by 81
#
#        resolved_at           closed_at
# 0  29/2/2016 11:29 2016-05-03 12:00:00
# 1  29/2/2016 11:29 2016-05-03 12:00:00
# 2  29/2/2016 11:29 2016-05-03 12:00:00
# 3  29/2/2016 11:29 2016-05-03 12:00:00
# 4   1/3/2016 09:52 2016-06-03 10:00:00
#
# [5 rows x 31 columns]

# %% [markdown]
# # Filling the NAN

# %%
data1.isnull().sum()
# Out:
# number                         0
# incident_state                 0
# active                         0
# reassignment_count             0
# reopen_count                   0
# sys_mod_count                  0
# made_sla                       0
# caller_id                     29
# opened_by                   4835
# opened_at                      0
# sys_created_by             53076
# sys_created_at             53076
# sys_updated_by                 0
# sys_updated_at                 0
# contact_type                   0
# location                      76
# category                      78
# subcategory                  111
# u_symptom                  32964
# impact                         0
# urgency                        0
# priority                       0
# assignment_group           14213
# assigned_to                27496
# knowledge                      0
# u_priority_confirmation        0
# notify                         0
# closed_code                  714
# resolved_by                  226
# resolved_at                 3141
# closed_at                      0
# dtype: int64

# %%
# creating a neww class for missing values  for caller id
data1['caller_id'].fillna(value='caller 4340',inplace=True)

# creating a neww class for missing values for opened by
data1['opened_by'].fillna(value = 'Opened by 4341', inplace=True)

# creating a neww class for missing values for sys created by
data1['sys_created_by'].fillna(value='Created by 4342', inplace=True)

# creating a neww class for missing values for location
data1['location'].fillna('Location 4343', inplace=True)

# creating a neww class for missing values for category
data1['category'].fillna('Category 4344',inplace=True)

# creating a neww class for missing values for subcategory
data1['subcategory'].fillna(value='Subcategory 4345',inplace=True)

# creating a neww class for missing values for symptoms
data1['u_symptom'].fillna(value='Symptom 4346', inplace=True)

# creating a neww class for missing values for assignment group
data1['assignment_group'].fillna(value='Group 4347',inplace=True)

# creating a neww class for missing values for resolver
data1['assigned_to'].fillna(value='Resolver 4348',inplace=True)


# replacing with mode
data1['closed_code'].fillna(data1['closed_code'].mode()[0],inplace=True)
data1['resolved_by'].fillna(data1['resolved_by'].mode()[0],inplace=True)

# %%
data1.isnull().sum()
# Out:
# number                         0
# incident_state                 0
# active                         0
# reassignment_count             0
# reopen_count                   0
# sys_mod_count                  0
# made_sla                       0
# caller_id                      0
# opened_by                      0
# opened_at                      0
# sys_created_by                 0
# sys_created_at             53076
# sys_updated_by                 0
# sys_updated_at                 0
# contact_type                   0
# location                       0
# category                       0
# subcategory                    0
# u_symptom                      0
# impact                         0
# urgency                        0
# priority                       0
# assignment_group               0
# assigned_to                    0
# knowledge                      0
# u_priority_confirmation        0
# notify                         0
# closed_code                    0
# resolved_by                    0
# resolved_at                 3141
# closed_at                      0
# dtype: int64

# %% [markdown]
# # Dropping Columns with missing data

# %%
data2 = data1.drop(['sys_created_at','resolved_at'], axis = 1)
data2.head()
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
# 2  INC0000045       Resolved    True                   0             0
# 3  INC0000045         Closed   False                   0             0
# 4  INC0000047            New    True                   0             0
#
#    sys_mod_count  made_sla    caller_id       opened_by           opened_at  \
# 0              0      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 1              2      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 2              3      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 3              4      True  Caller 2403    Opened by  8 2016-02-29 01:16:00
# 4              0      True  Caller 2403  Opened by  397 2016-02-29 04:40:00
#
#    ...     urgency      priority assignment_group    assigned_to knowledge  \
# 0  ...  2 - Medium  3 - Moderate         Group 56  Resolver 4348      True
# 1  ...  2 - Medium  3 - Moderate         Group 56  Resolver 4348      True
# 2  ...  2 - Medium  3 - Moderate         Group 56  Resolver 4348      True
# 3  ...  2 - Medium  3 - Moderate         Group 56  Resolver 4348      True
# 4  ...  2 - Medium  3 - Moderate         Group 70    Resolver 89      True
#
#   u_priority_confirmation         notify closed_code      resolved_by  \
# 0                   False  Do Not Notify      code 5  Resolved by 149
# 1                   False  Do Not Notify      code 5  Resolved by 149
# 2                   False  Do Not Notify      code 5  Resolved by 149
# 3                   False  Do Not Notify      code 5  Resolved by 149
# 4                   False  Do Not Notify      code 5   Resolved by 81
#
#             closed_at
# 0 2016-05-03 12:00:00
# 1 2016-05-03 12:00:00
# 2 2016-05-03 12:00:00
# 3 2016-05-03 12:00:00
# 4 2016-06-03 10:00:00
#
# [5 rows x 29 columns]

# %% [markdown]
# # Labelencoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()

# %%
columns_to_be_label_encoded =['active',
                         'made_sla',
                         'contact_type',
                         'knowledge',
                         'u_priority_confirmation',
                         'notify',
                         'incident_state',
                         'caller_id',
                         'opened_by',
                         'sys_created_by',
                         'sys_updated_by',
                         'location',
                         'category',
                         'subcategory',
                         'u_symptom',
                         'assignment_group',
                         'assigned_to',
                         'closed_code',
                         'resolved_by',
                         'number',
                        'impact',
                        'urgency',
                        'priority']

# %%
for i in columns_to_be_label_encoded:
    data2[i] = labelencoder.fit_transform(data2[i])

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141712 entries, 0 to 141711
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   number                   141712 non-null  int32
#  1   incident_state           141712 non-null  int32
#  2   active                   141712 non-null  int64
#  3   reassignment_count       141712 non-null  int64
#  4   reopen_count             141712 non-null  int64
#  5   sys_mod_count            141712 non-null  int64
#  6   made_sla                 141712 non-null  int64
#  7   caller_id                141712 non-null  int32
#  8   opened_by                141712 non-null  int32
#  9   opened_at                141712 non-null  datetime64[ns]
#  10  sys_created_by           141712 non-null  int32
#  11  sys_updated_by           141712 non-null  int32
#  12  sys_updated_at           141712 non-null  object
#  13  contact_type             141712 non-null  int32
#  14  location                 141712 non-null  int32
#  15  category                 141712 non-null  int32
#  16  subcategory              141712 non-null  int32
#  17  u_symptom                141712 non-null  int32
#  18  impact                   141712 non-null  int32
#  19  urgency                  141712 non-null  int32
#  20  priority                 141712 non-null  int32
#  21  assignment_group         141712 non-null  int32
#  22  assigned_to              141712 non-null  int32
#  23  knowledge                141712 non-null  int64
#  24  u_priority_confirmation  141712 non-null  int64
#  25  notify                   141712 non-null  int32
#  26  closed_code              141712 non-null  int32
#  27  resolved_by              141712 non-null  int32
#  28  closed_at                141712 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int32(19), int64(7), object(1)
# memory usage: 21.1+ MB

# %%
data2.head()
# Out:
#    number  incident_state  active  reassignment_count  reopen_count  \
# 0       0               7       1                   0             0
# 1       0               8       1                   0             0
# 2       0               8       1                   0             0
# 3       0               6       0                   0             0
# 4       1               7       1                   0             0
#
#    sys_mod_count  made_sla  caller_id  opened_by           opened_at  ...  \
# 0              0         1       1462        200 2016-02-29 01:16:00  ...
# 1              2         1       1462        200 2016-02-29 01:16:00  ...
# 2              3         1       1462        200 2016-02-29 01:16:00  ...
# 3              4         1       1462        200 2016-02-29 01:16:00  ...
# 4              0         1       1462        120 2016-02-29 04:40:00  ...
#
#    urgency  priority assignment_group  assigned_to  knowledge  \
# 0        1         2               48          181          1
# 1        1         2               48          181          1
# 2        1         2               48          181          1
# 3        1         2               48          181          1
# 4        1         2               64          224          1
#
#    u_priority_confirmation  notify  closed_code  resolved_by  \
# 0                        0       0           12           51
# 1                        0       0           12           51
# 2                        0       0           12           51
# 3                        0       0           12           51
# 4                        0       0           12          196
#
#             closed_at
# 0 2016-05-03 12:00:00
# 1 2016-05-03 12:00:00
# 2 2016-05-03 12:00:00
# 3 2016-05-03 12:00:00
# 4 2016-06-03 10:00:00
#
# [5 rows x 29 columns]

# %%
data2.describe()
# Out:
#               number  incident_state         active  reassignment_count  \
# count  141712.000000   141712.000000  141712.000000       141712.000000
# mean    11711.962614        5.031649       0.823685            1.104197
# std      7357.929618        2.707264       0.381090            1.734673
# min         0.000000        0.000000       0.000000            0.000000
# 25%      5056.000000        1.000000       1.000000            0.000000
# 50%     11317.000000        6.000000       1.000000            1.000000
# 75%     18158.000000        7.000000       1.000000            1.000000
# max     24917.000000        8.000000       1.000000           27.000000
#
#         reopen_count  sys_mod_count       made_sla      caller_id  \
# count  141712.000000  141712.000000  141712.000000  141712.000000
# mean        0.021918       5.080946       0.934974    2642.995470
# std         0.207302       7.680652       0.246573    1505.681869
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       1.000000       1.000000    1340.000000
# 50%         0.000000       3.000000       1.000000    2661.000000
# 75%         0.000000       6.000000       1.000000    3927.000000
# max         8.000000     129.000000       1.000000    5244.000000
#
#            opened_by  sys_created_by  ...         impact        urgency  \
# count  141712.000000   141712.000000  ...  141712.000000  141712.000000
# mean       89.929209       95.893298  ...       1.002787       0.997022
# std        67.616691       58.009134  ...       0.228142       0.231837
# min         0.000000        0.000000  ...       0.000000       0.000000
# 25%        31.000000       24.000000  ...       1.000000       1.000000
# 50%        60.000000      134.000000  ...       1.000000       1.000000
# 75%       164.000000      134.000000  ...       1.000000       1.000000
# max       207.000000      185.000000  ...       2.000000       2.000000
#
#             priority  assignment_group    assigned_to      knowledge  \
# count  141712.000000     141712.000000  141712.000000  141712.000000
# mean        1.975598         42.524387     125.306615       0.178976
# std         0.335485         21.604322      63.847328       0.383333
# min         0.000000          0.000000       0.000000       0.000000
# 25%         2.000000         19.000000      73.000000       0.000000
# 50%         2.000000         46.000000     139.000000       0.000000
# 75%         2.000000         64.000000     181.000000       0.000000
# max         3.000000         78.000000     234.000000       1.000000
#
#        u_priority_confirmation         notify    closed_code    resolved_by
# count            141712.000000  141712.000000  141712.000000  141712.000000
# mean                  0.289122       0.000840      12.820629      90.077079
# std                   0.453356       0.028966       2.925610      61.365941
# min                   0.000000       0.000000       0.000000       0.000000
# 25%                   0.000000       0.000000      13.000000      37.000000
# 50%                   0.000000       0.000000      13.000000      81.000000
# 75%                   1.000000       0.000000      14.000000     142.000000
# max                   1.000000       1.000000      16.000000     215.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
###Histogram 
data2.hist(figsize=(20 , 18))
plt.show()

# %%
# 'impact' - This a very important field as based on this a service company calculates profit or penalty
# This plays a major role in our Incident resolution time as well
fig_dims = (7, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(data['impact'],ax=ax)
plt.title("Impact Details", size = 14)
plt.xlabel("Impact Type", size=12)
plt.ylabel("Count", size=12)
#plt.xticks(rotation=90)
plt.grid()
plt.show()
data2['impact'].value_counts()
# Out:
# C:\Users\farhanfarooq\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1    134335
# 2      3886
# 0      3491
# Name: impact, dtype: int64

# %%
# 'urgency' - This a very important field as based which the ticket is being handled
# This plays a major role in our Incident resolution time as well
fig_dims = (7, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(data['urgency'],ax=ax)
plt.title("urgency Details", size = 14)
plt.xlabel("urgency Type", size=12)
plt.ylabel("Count", size=12)
plt.grid()
plt.show()
data2['urgency'].value_counts()
# Out:
# C:\Users\farhanfarooq\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1    134094
# 0      4020
# 2      3598
# Name: urgency, dtype: int64

# %%
# ''priority' - Combination of both Impact and urgency
# This plays a major role in our Incident resolution time as well
fig_dims = (7, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(data['priority'],ax=ax)
plt.title("priority Details", size = 14)
plt.xlabel("priority Type", size=12)
plt.ylabel("Count", size=12)
#plt.xticks(rotation=90)
plt.grid()
plt.show()
data2['priority'].value_counts()
# Out:
# C:\Users\farhanfarooq\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 2    132452
# 3      4030
# 1      2972
# 0      2258
# Name: priority, dtype: int64

# %%
# Incident closure details
fig_dims = (14, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(data['closed_code'],ax=ax)
plt.title("closed_code Details", size = 14)
plt.xlabel("closed_code Type", size=12)
plt.ylabel("Count", size=12)
plt.grid()
plt.show()
data2['closed_code'].value_counts()
# Out:
# C:\Users\farhanfarooq\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 13    87297
# 14    20733
# 16    13562
# 15     5646
# 12     4469
# 0      3265
# 1      1678
# 2      1493
# 11     1139
# 7      1091
# 10      608
# 9       349
# 6       183
# 8       115
# 4        59
# 3        13
# 5        12
# Name: closed_code, dtype: int64

# %%
# 'category'
fig_dims = (18, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(data2['category'],ax=ax)
plt.title("category Details", size = 14)
plt.xlabel("category Type", size=12)
plt.ylabel("Count", size=12)
plt.xticks(rotation=90)
plt.grid()
plt.show()
# Out:
# C:\Users\farhanfarooq\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig_dims = (15, 15)
corr = data2.corr()
sns.heatmap(corr, annot=True, square=True)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# # Create seperate columns for day , date & year to perform feature selection

# %%
data2["opened_at_day"]=pd.to_datetime(data2.opened_at).dt.day
data2["opened_at_month"]=pd.to_datetime(data2.opened_at).dt.month
data2["opened_at_year"]=pd.to_datetime(data2.opened_at).dt.year
data2["opened_at_hr"]=pd.to_datetime(data2.opened_at).dt.hour
data2["opened_at_minute"]=pd.to_datetime(data2.opened_at).dt.minute

data2["closed_at_day"]=pd.to_datetime(data2.closed_at).dt.day
data2["closed_at_month"]=pd.to_datetime(data2.closed_at).dt.month
data2["closed_at_year"]=pd.to_datetime(data2.closed_at).dt.year
data2["closed_at_hr"]=pd.to_datetime(data2.closed_at).dt.hour
data2["closed_at_minute"]=pd.to_datetime(data2.closed_at).dt.minute

# %%
data2.drop(['opened_at','closed_at'],axis=1,inplace=True)

# %%
data2.drop(['sys_updated_at'],axis=1,inplace=True)

# %%
data2.head()
# Out:
#    number  incident_state  active  reassignment_count  reopen_count  \
# 0       0               7       1                   0             0
# 1       0               8       1                   0             0
# 2       0               8       1                   0             0
# 3       0               6       0                   0             0
# 4       1               7       1                   0             0
#
#    sys_mod_count  made_sla  caller_id  opened_by  sys_created_by  ...  \
# 0              0         1       1462        200             152  ...
# 1              2         1       1462        200             152  ...
# 2              3         1       1462        200             152  ...
# 3              4         1       1462        200             152  ...
# 4              0         1       1462        120              58  ...
#
#    opened_at_day  opened_at_month  opened_at_year  opened_at_hr  \
# 0             29                2            2016             1
# 1             29                2            2016             1
# 2             29                2            2016             1
# 3             29                2            2016             1
# 4             29                2            2016             4
#
#    opened_at_minute  closed_at_day  closed_at_month  closed_at_year  \
# 0                16              3                5            2016
# 1                16              3                5            2016
# 2                16              3                5            2016
# 3                16              3                5            2016
# 4                40              3                6            2016
#
#    closed_at_hr  closed_at_minute
# 0            12                 0
# 1            12                 0
# 2            12                 0
# 3            12                 0
# 4            10                 0
#
# [5 rows x 36 columns]

# %% [markdown]
# # Spliting the data into X & Y variables

# %%
x = data2.drop('impact',axis=1)

# %%
y = data2['impact']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: impact, dtype: int32

# %% [markdown]
# # Train and Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3,random_state=10)

# %% [markdown]
# # Balancing The Data

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
x_train_smote,y_train_smote = sm.fit_resample(x_train.astype('float'),y_train)

# %%
from collections import Counter
print("Before SMOTE :",Counter(y_train))
print("After SMOTE :",Counter(y_train_smote))
# Out:
# Before SMOTE : Counter({1: 94076, 2: 2714, 0: 2408})
# After SMOTE : Counter({1: 94076, 2: 94076, 0: 94076})

# %% [markdown]
# # Feature selection

# %% [markdown]
# # Feature selection using Chi-Square

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
ordered_rank_feature=SelectKBest(score_func=chi2,k=16)
ordered_feature=ordered_rank_feature.fit(x_train_smote,y_train_smote)
ordered_feature
# Out:
# SelectKBest(k=16, score_func=<function chi2 at 0x0000015ABBFFB790>)

# %%
df_scores=pd.DataFrame(ordered_feature.scores_,columns=['scores'])
df_columns=pd.DataFrame(x_train.columns)
features_rank=pd.concat([df_scores,df_columns],axis=1)
features_rank.nlargest(10,'scores')

#These are top 10 features useful for predicting impact
# Out:
#           scores                 0
# 0   5.489010e+07            number
# 8   1.489334e+06         opened_by
# 9   2.501975e+05    sys_created_by
# 10  2.350332e+05    sys_updated_by
# 17  1.893693e+05          priority
# 16  1.033814e+05           urgency
# 24  8.445939e+04       resolved_by
# 34  7.385006e+04  closed_at_minute
# 19  6.908591e+04       assigned_to
# 7   3.684925e+04         caller_id

# %% [markdown]
# # Feature selection using ExtraTreeClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(x_train_smote,y_train_smote)
# Out:
# ExtraTreesClassifier()

# %%
model.feature_importances_
# Out:
# array([9.29116202e-03, 8.11177547e-03, 9.17641184e-03, 3.36686342e-03,
#        5.87994119e-04, 2.68611763e-03, 8.77444748e-03, 4.71411152e-03,
#        2.88369796e-02, 1.60801641e-02, 4.66587694e-03, 2.40318059e-04,
#        5.97439817e-03, 8.10788373e-03, 4.96636281e-03, 4.20000765e-03,
#        2.81480482e-01, 4.98250546e-01, 6.41890269e-03, 5.51841512e-03,
#        1.26922193e-02, 1.43133306e-02, 8.09575769e-06, 3.86131059e-03,
#        8.32625519e-03, 5.70540332e-03, 6.60820661e-03, 4.43767067e-04,
#        1.02809068e-02, 3.82989078e-03, 5.44025716e-03, 4.70210915e-03,
#        5.67692179e-04, 5.45255171e-03, 6.31878332e-03])

# %%
ranked_features=pd.Series(model.feature_importances_,index=x_train.columns)
ranked_features.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# # Feature selection using DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

model= DecisionTreeClassifier()
model.fit(x_train_smote,y_train_smote)
# Out:
# DecisionTreeClassifier()

# %%
feature = pd.Series(model.feature_importances_)
feature.index = x_train.columns
feature.sort_values(ascending=False)
# Out:
# priority                   9.840467e-01
# urgency                    1.495360e-02
# subcategory                4.183886e-04
# opened_by                  1.286016e-04
# caller_id                  8.425423e-05
# reassignment_count         7.935831e-05
# opened_at_minute           7.751806e-05
# sys_created_by             6.754395e-05
# location                   5.189502e-05
# sys_mod_count              5.029110e-05
# assigned_to                2.118363e-05
# number                     7.967816e-06
# closed_at_day              5.314852e-06
# opened_at_day              5.314852e-06
# closed_at_hr               7.833670e-07
# incident_state             4.754489e-07
# closed_code                3.156058e-07
# opened_at_hr               3.115015e-07
# active                     2.247796e-07
# resolved_by                0.000000e+00
# closed_at_year             0.000000e+00
# closed_at_month            0.000000e+00
# opened_at_year             0.000000e+00
# opened_at_month            0.000000e+00
# contact_type               0.000000e+00
# category                   0.000000e+00
# notify                     0.000000e+00
# u_priority_confirmation    0.000000e+00
# knowledge                  0.000000e+00
# reopen_count               0.000000e+00
# assignment_group           0.000000e+00
# made_sla                   0.000000e+00
# u_symptom                  0.000000e+00
# sys_updated_by             0.000000e+00
# closed_at_minute           0.000000e+00
# dtype: float64

# %%
feature.sort_values(ascending=False).plot.bar(figsize=(15, 4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature Selection using Mutual information

# %%
from sklearn.feature_selection import mutual_info_classif
# determine the mutual information
mutual_info = mutual_info_classif(x_train_smote, y_train_smote)
mutual_info
# Out:
# array([0.69731822, 0.25242117, 0.08821469, 0.1652993 , 0.00445419,
#        0.48440035, 0.07251906, 0.60542321, 0.48628644, 0.33709516,
#        0.38204776, 0.02712981, 0.19154279, 0.25454399, 0.27292614,
#        0.22901129, 0.76411159, 1.0922544 , 0.33247869, 0.37379876,
#        0.02637985, 0.1018946 , 0.        , 0.09332688, 0.3735824 ,
#        0.08451437, 0.04672462, 0.01560263, 0.1855109 , 0.17505266,
#        0.10885444, 0.08830894, 0.01729546, 0.15368667, 0.08087084])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = x_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# priority                   1.092254
# urgency                    0.764112
# number                     0.697318
# caller_id                  0.605423
# opened_by                  0.486286
# sys_mod_count              0.484400
# sys_updated_by             0.382048
# assigned_to                0.373799
# resolved_by                0.373582
# sys_created_by             0.337095
# assignment_group           0.332479
# subcategory                0.272926
# category                   0.254544
# incident_state             0.252421
# u_symptom                  0.229011
# location                   0.191543
# opened_at_hr               0.185511
# opened_at_minute           0.175053
# reassignment_count         0.165299
# closed_at_hr               0.153687
# closed_at_day              0.108854
# u_priority_confirmation    0.101895
# closed_code                0.093327
# closed_at_month            0.088309
# active                     0.088215
# opened_at_day              0.084514
# closed_at_minute           0.080871
# made_sla                   0.072519
# opened_at_month            0.046725
# contact_type               0.027130
# knowledge                  0.026380
# closed_at_year             0.017295
# opened_at_year             0.015603
# reopen_count               0.004454
# notify                     0.000000
# dtype: float64

# %%
#let's plot the ordered mutual_info values per feature
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15, 4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Using important features which have been obtained after feature selection

# %%
x_train_smote_new= x_train_smote[['priority','urgency','number','caller_id','opened_by','sys_mod_count','sys_updated_by','assigned_to','resolved_by','sys_created_by']]
x_test_new= x_test[['priority','urgency','number','caller_id','opened_by','sys_mod_count','sys_updated_by','assigned_to','resolved_by','sys_created_by']]

# %%
#priority                   1.092273
#urgency                    0.763277
#number                     0.697298
#caller_id                  0.605181
#opened_by                  0.486503
#sys_mod_count              0.483351
#sys_updated_by             0.380200
#assigned_to                0.376061
#resolved_by                0.372394
#sys_created_by

# %% [markdown]
# # Model Validation Methods

# %% [markdown]
# # KNN Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kfold = KFold(n_splits=10)
model = KNeighborsClassifier(n_neighbors=17)

results = cross_val_score(model, x_train_smote_new, y_train_smote, cv=kfold)

print(results.mean())
# Out:
# 0.9112850291582081

# %%
model.fit(x_train_smote_new,y_train_smote)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
# Predicting the model
y_predict_knn = model.predict(x_test_new)

# %%
# Finding accuracy, precision, recall and confusion matrix
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print(accuracy_score(y_test,y_predict_knn))
print(classification_report(y_test,y_predict_knn))
# Out:
# 0.818765583102037
#               precision    recall  f1-score   support
#
#            0       0.20      0.87      0.32      1083
#            1       0.99      0.82      0.90     40259
#            2       0.22      0.90      0.36      1172
#
#     accuracy                           0.82     42514
#    macro avg       0.47      0.86      0.52     42514
# weighted avg       0.95      0.82      0.87     42514

# %%
confusion_matrix(y_test,y_predict_knn )
# Out:
# array([[  944,   116,    23],
#        [ 3812, 32814,  3633],
#        [   27,    94,  1051]], dtype=int64)

# %%
accuracy_knn = results.mean()*100

# %%
accuracy_knn
# Out:
# 91.1285029158208

# %% [markdown]
# # Gaussian Naive Bayes Classification

# %%
from sklearn.naive_bayes import GaussianNB

kfold = KFold(n_splits=10)
model = GaussianNB()
results = cross_val_score(model, x_train_smote_new, y_train_smote, cv=kfold)
print(results.mean())
# Out:
# 0.9931615666116105

# %%
model.fit(x_train_smote_new,y_train_smote)
# Out:
# GaussianNB()

# %%
# Predicting the model
y_predict_NB = model.predict(x_test_new)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_test,y_predict_NB))
print(classification_report(y_test,y_predict_NB))
# Out:
# 0.9868043468034059
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81      1083
#            1       1.00      0.99      0.99     40259
#            2       0.96      0.99      0.97      1172
#
#     accuracy                           0.99     42514
#    macro avg       0.88      0.99      0.93     42514
# weighted avg       0.99      0.99      0.99     42514

# %%
confusion_matrix(y_test,y_predict_NB )
# Out:
# array([[ 1080,     3,     0],
#        [  496, 39709,    54],
#        [    5,     3,  1164]], dtype=int64)

# %%
accuracy_NB = results.mean()*100

# %%
accuracy_NB
# Out:
# 99.31615666116105

# %% [markdown]
# # RandomForestClassification

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

kfold = KFold(n_splits=10)
model_rf = RandomForestClassifier()
results = cross_val_score(model, x_train_smote_new, y_train_smote, cv=kfold)
print(results.mean())
# Out:
# 0.9999362221045484

# %%
model_rf.fit(x_train_smote_new,y_train_smote)
# Out:
# RandomForestClassifier()

# %%
# Predicting the model
y_predict_rf = model_rf.predict(x_test_new)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_test,y_predict_rf))
print(classification_report(y_test,y_predict_rf))
# Out:
# 0.9999529566730959
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1083
#            1       1.00      1.00      1.00     40259
#            2       1.00      1.00      1.00      1172
#
#     accuracy                           1.00     42514
#    macro avg       1.00      1.00      1.00     42514
# weighted avg       1.00      1.00      1.00     42514

# %%
accuracy_rf = results.mean()*100

# %%
accuracy_rf
# Out:
# 99.99362221045483

# %% [markdown]
# # DecissionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
kfold = KFold(n_splits=10)
model = DecisionTreeClassifier()
results = cross_val_score(model, x_train_smote_new, y_train_smote, cv=kfold)
print(results.mean())
# Out:
# 0.9998972460474314

# %%
model.fit(x_train_smote_new,y_train_smote)
# Out:
# DecisionTreeClassifier()

# %%
# Predicting the model
y_predict_dtree = model.predict(x_test_new)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_test,y_predict_dtree))
print(classification_report(y_test,y_predict_dtree))
# Out:
# 0.9999529566730959
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1083
#            1       1.00      1.00      1.00     40259
#            2       1.00      1.00      1.00      1172
#
#     accuracy                           1.00     42514
#    macro avg       1.00      1.00      1.00     42514
# weighted avg       1.00      1.00      1.00     42514

# %%
accuracy_dtree = results.mean()*100

# %%
accuracy_dtree
# Out:
# 99.98972460474313

# %%
data = {"MODEL":pd.Series(["Random forest","Decision tree","Gaussian NB",'KNN']),
        "Accuracy":pd.Series([accuracy_rf,accuracy_dtree,accuracy_knn,accuracy_NB])}
table=pd.DataFrame(data)
table
# Out:
#            MODEL   Accuracy
# 0  Random forest  99.993622
# 1  Decision tree  99.989725
# 2    Gaussian NB  91.128503
# 3            KNN  99.316157

# %% [markdown]
# # Impact prediction using Random forest model showed the highest accuracy and f1-score. Therefore, this model is used for deployment to predict the impact of the incidents. (High,Medium and Low)

# %%
import pickle
pickle_out = open("RandomForest.pkl","wb")
pickle.dump(model_rf, pickle_out)
pickle_out.close()
